# %%
import pandas as pd
import pingouin as pg
import numpy as np
import random
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, kendalltau
from read_data import *

from sdt_constrained_probit_glmm import (
    prepare_sdt_dataframe, sdt_constrained_formula,
    fit_sdt_probit_glm, reference_delta_grid,
    sdt_from_model
)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load and preprocess the data

# %%
allsubjdata = pd.read_csv('data/allsubjdata.csv')

# %%
allsubjdata.loc[allsubjdata['corr_resp']=='f','int_diff'] = 0.0

# %%
allsubjdata['abs_diff'] = allsubjdata['int_diff'].abs()

# %%
exclude_subjs = subject_exclusion(allsubjdata)
allsubjdata_noexcl = allsubjdata.copy()
allsubjdata = allsubjdata[~allsubjdata.subject.isin(exclude_subjs)]
print(f'Excluded {len(exclude_subjs)} out of {allsubjdata_noexcl.subject.nunique()} subjects.')
print('Final sample size:', allsubjdata.subject.nunique())
# Out:
# Excluded 126 out of 277 subjects.
# Final sample size: 151

# %%
allsubjdata
# Out:
#        scene  expected  initview  finalview  \
# 384      7.0       0.0      -1.0       90.0
# 385      1.0       1.0      -1.0       30.0
# 386     10.0       1.0      -1.0       90.0
# 387      3.0       1.0       2.0       90.0
# 388      1.0       0.0       2.0       30.0
# ...      ...       ...       ...        ...
# 53179    1.0       0.0      -1.0       30.0
# 53180    7.0       0.0      -1.0       90.0
# 53181    1.0       0.0       2.0       90.0
# 53182    3.0       0.0      -1.0       90.0
# 53183   10.0       0.0      -1.0       30.0
#
#                                                  img_2  \
# 384     Zoom_Sequences_FixedLight/Scene7_-1.0_0020.png
# 385     Zoom_Sequences_FixedLight/Scene1_-1.0_0015.png
# 386    Zoom_Sequences_FixedLight/Scene10_-1.0_0035.png
# 387      Zoom_Sequences_FixedLight/Scene3_2.0_0015.png
# 388      Zoom_Sequences_FixedLight/Scene1_2.0_0015.png
# ...                                                ...
# 53179   Zoom_Sequences_FixedLight/Scene1_-1.0_0015.png
# 53180   Zoom_Sequences_FixedLight/Scene7_-1.0_0025.png
# 53181    Zoom_Sequences_FixedLight/Scene1_2.0_0015.png
# 53182   Zoom_Sequences_FixedLight/Scene3_-1.0_0020.png
# 53183  Zoom_Sequences_FixedLight/Scene10_-1.0_0015.png
#
#                                                  img_3  \
# 384     Zoom_Sequences_FixedLight/Scene7_-1.0_0040.png
# 385     Zoom_Sequences_FixedLight/Scene1_-1.0_0020.png
# 386    Zoom_Sequences_FixedLight/Scene10_-1.0_0050.png
# 387      Zoom_Sequences_FixedLight/Scene3_2.0_0020.png
# 388      Zoom_Sequences_FixedLight/Scene1_2.0_0020.png
# ...                                                ...
# 53179   Zoom_Sequences_FixedLight/Scene1_-1.0_0020.png
# 53180   Zoom_Sequences_FixedLight/Scene7_-1.0_0030.png
# 53181    Zoom_Sequences_FixedLight/Scene1_2.0_0020.png
# 53182   Zoom_Sequences_FixedLight/Scene3_-1.0_0045.png
# 53183  Zoom_Sequences_FixedLight/Scene10_-1.0_0020.png
#
#                                                  img_4  \
# 384     Zoom_Sequences_FixedLight/Scene7_-1.0_0055.png
# 385     Zoom_Sequences_FixedLight/Scene1_-1.0_0025.png
# 386    Zoom_Sequences_FixedLight/Scene10_-1.0_0055.png
# 387      Zoom_Sequences_FixedLight/Scene3_2.0_0030.png
# 388      Zoom_Sequences_FixedLight/Scene1_2.0_0025.png
# ...                                                ...
# 53179   Zoom_Sequences_FixedLight/Scene1_-1.0_0025.png
# 53180   Zoom_Sequences_FixedLight/Scene7_-1.0_0050.png
# 53181    Zoom_Sequences_FixedLight/Scene1_2.0_0040.png
# 53182   Zoom_Sequences_FixedLight/Scene3_-1.0_0060.png
# 53183  Zoom_Sequences_FixedLight/Scene10_-1.0_0025.png
#
#                                                  probe_1  \
# 384    Translate_Views_FixedLight/Scene7_2.0_0090_0.0...
# 385    Translate_Views_FixedLight/Scene1_-1.0_0030_0....
# 386    Translate_Views_FixedLight/Scene10_-1.0_0090_-...
# 387    Translate_Views_FixedLight/Scene3_2.0_0090_0.0...
# 388    Translate_Views_FixedLight/Scene1_-1.0_0030_0....
# ...                                                  ...
# 53179  Translate_Views_FixedLight/Scene1_2.0_0030_0.0...
# 53180  Translate_Views_FixedLight/Scene7_2.0_0090_-0....
# 53181  Translate_Views_FixedLight/Scene1_-1.0_0090_0....
# 53182  Translate_Views_FixedLight/Scene3_2.0_0090_0.0...
# 53183  Translate_Views_FixedLight/Scene10_2.0_0030_-0...
#
#                                                  probe_2  int_diff  p_exp  \
# 384    Translate_Views_FixedLight/Scene7_2.0_0090_0.5...      0.50   0.75
# 385    Translate_Views_FixedLight/Scene1_-1.0_0030_0....      0.55   0.75
# 386    Translate_Views_FixedLight/Scene10_-1.0_0090_-...      0.00   0.75
# 387    Translate_Views_FixedLight/Scene3_2.0_0090_0.0...      0.00   0.75
# 388    Translate_Views_FixedLight/Scene1_-1.0_0030_0....      0.55   0.75
# ...                                                  ...       ...    ...
# 53179  Translate_Views_FixedLight/Scene1_2.0_0030_1.0...      0.95   0.25
# 53180  Translate_Views_FixedLight/Scene7_2.0_0090_-1....     -0.95   0.25
# 53181  Translate_Views_FixedLight/Scene1_-1.0_0090_0....      0.00   0.25
# 53182  Translate_Views_FixedLight/Scene3_2.0_0090_0.0...      0.00   0.25
# 53183  Translate_Views_FixedLight/Scene10_2.0_0030_-0...     -0.90   0.25
#
#       response corr_resp  hit      rt  subject      date           time  \
# 384          f         j  0.0  1530.0      914  20220511  1652269532447
# 385          f         j  0.0  1326.3      914  20220511  1652269532447
# 386          f         f  1.0  1416.0      914  20220511  1652269532447
# 387          f         f  1.0  1727.5      914  20220511  1652269532447
# 388          j         j  1.0  1468.4      914  20220511  1652269532447
# ...        ...       ...  ...     ...      ...       ...            ...
# 53179      NaN         j  NaN     NaN     1459  20220910  1662807993840
# 53180        j         j  1.0   475.6     1459  20220910  1662807993840
# 53181        f         f  1.0   398.3     1459  20220910  1662807993840
# 53182        f         f  1.0   344.6     1459  20220910  1662807993840
# 53183        j         j  1.0   561.5     1459  20220910  1662807993840
#
#        abs_diff
# 384        0.50
# 385        0.55
# 386        0.00
# 387        0.00
# 388        0.55
# ...         ...
# 53179      0.95
# 53180      0.95
# 53181      0.00
# 53182      0.00
# 53183      0.90
#
# [28992 rows x 19 columns]

# %%
allsubjdata = allsubjdata.dropna(subset = ['response'])

# %%
trial_type = ['same' if r == 'f' else 'diff' for r in allsubjdata.corr_resp.values]
allsubjdata.loc[:, 'trial_type'] = trial_type

resp_diff = [0 if r == 'f' else 1 for r in allsubjdata.response.values]
allsubjdata.loc[:, 'resp_diff'] = resp_diff
# Out:
# /var/folders/8d/bvdwvdxj3s98cz8_ylgl_9j00000gn/T/ipykernel_7992/1287962830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allsubjdata.loc[:, 'trial_type'] = trial_type
# /var/folders/8d/bvdwvdxj3s98cz8_ylgl_9j00000gn/T/ipykernel_7992/1287962830.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allsubjdata.loc[:, 'resp_diff'] = resp_diff

# %%
df_sdt = prepare_sdt_dataframe(allsubjdata)

# %%
df_sdt
# Out:
#        scene cond  initview  finalview  \
# 384      7.0    0      -1.0       90.0
# 385      1.0    1      -1.0       30.0
# 386     10.0    1      -1.0       90.0
# 387      3.0    1       2.0       90.0
# 388      1.0    0       2.0       30.0
# ...      ...  ...       ...        ...
# 53178    3.0    1       2.0       90.0
# 53180    7.0    0      -1.0       90.0
# 53181    1.0    0       2.0       90.0
# 53182    3.0    0      -1.0       90.0
# 53183   10.0    0      -1.0       30.0
#
#                                                  img_2  \
# 384     Zoom_Sequences_FixedLight/Scene7_-1.0_0020.png
# 385     Zoom_Sequences_FixedLight/Scene1_-1.0_0015.png
# 386    Zoom_Sequences_FixedLight/Scene10_-1.0_0035.png
# 387      Zoom_Sequences_FixedLight/Scene3_2.0_0015.png
# 388      Zoom_Sequences_FixedLight/Scene1_2.0_0015.png
# ...                                                ...
# 53178    Zoom_Sequences_FixedLight/Scene3_2.0_0025.png
# 53180   Zoom_Sequences_FixedLight/Scene7_-1.0_0025.png
# 53181    Zoom_Sequences_FixedLight/Scene1_2.0_0015.png
# 53182   Zoom_Sequences_FixedLight/Scene3_-1.0_0020.png
# 53183  Zoom_Sequences_FixedLight/Scene10_-1.0_0015.png
#
#                                                  img_3  \
# 384     Zoom_Sequences_FixedLight/Scene7_-1.0_0040.png
# 385     Zoom_Sequences_FixedLight/Scene1_-1.0_0020.png
# 386    Zoom_Sequences_FixedLight/Scene10_-1.0_0050.png
# 387      Zoom_Sequences_FixedLight/Scene3_2.0_0020.png
# 388      Zoom_Sequences_FixedLight/Scene1_2.0_0020.png
# ...                                                ...
# 53178    Zoom_Sequences_FixedLight/Scene3_2.0_0030.png
# 53180   Zoom_Sequences_FixedLight/Scene7_-1.0_0030.png
# 53181    Zoom_Sequences_FixedLight/Scene1_2.0_0020.png
# 53182   Zoom_Sequences_FixedLight/Scene3_-1.0_0045.png
# 53183  Zoom_Sequences_FixedLight/Scene10_-1.0_0020.png
#
#                                                  img_4  \
# 384     Zoom_Sequences_FixedLight/Scene7_-1.0_0055.png
# 385     Zoom_Sequences_FixedLight/Scene1_-1.0_0025.png
# 386    Zoom_Sequences_FixedLight/Scene10_-1.0_0055.png
# 387      Zoom_Sequences_FixedLight/Scene3_2.0_0030.png
# 388      Zoom_Sequences_FixedLight/Scene1_2.0_0025.png
# ...                                                ...
# 53178    Zoom_Sequences_FixedLight/Scene3_2.0_0055.png
# 53180   Zoom_Sequences_FixedLight/Scene7_-1.0_0050.png
# 53181    Zoom_Sequences_FixedLight/Scene1_2.0_0040.png
# 53182   Zoom_Sequences_FixedLight/Scene3_-1.0_0060.png
# 53183  Zoom_Sequences_FixedLight/Scene10_-1.0_0025.png
#
#                                                  probe_1  \
# 384    Translate_Views_FixedLight/Scene7_2.0_0090_0.0...
# 385    Translate_Views_FixedLight/Scene1_-1.0_0030_0....
# 386    Translate_Views_FixedLight/Scene10_-1.0_0090_-...
# 387    Translate_Views_FixedLight/Scene3_2.0_0090_0.0...
# 388    Translate_Views_FixedLight/Scene1_-1.0_0030_0....
# ...                                                  ...
# 53178  Translate_Views_FixedLight/Scene3_2.0_0090_0.0...
# 53180  Translate_Views_FixedLight/Scene7_2.0_0090_-0....
# 53181  Translate_Views_FixedLight/Scene1_-1.0_0090_0....
# 53182  Translate_Views_FixedLight/Scene3_2.0_0090_0.0...
# 53183  Translate_Views_FixedLight/Scene10_2.0_0030_-0...
#
#                                                  probe_2  int_diff  ...  \
# 384    Translate_Views_FixedLight/Scene7_2.0_0090_0.5...      0.50  ...
# 385    Translate_Views_FixedLight/Scene1_-1.0_0030_0....      0.55  ...
# 386    Translate_Views_FixedLight/Scene10_-1.0_0090_-...      0.00  ...
# 387    Translate_Views_FixedLight/Scene3_2.0_0090_0.0...      0.00  ...
# 388    Translate_Views_FixedLight/Scene1_-1.0_0030_0....      0.55  ...
# ...                                                  ...       ...  ...
# 53178  Translate_Views_FixedLight/Scene3_2.0_0090_-0....     -0.95  ...
# 53180  Translate_Views_FixedLight/Scene7_2.0_0090_-1....     -0.95  ...
# 53181  Translate_Views_FixedLight/Scene1_-1.0_0090_0....      0.00  ...
# 53182  Translate_Views_FixedLight/Scene3_2.0_0090_0.0...      0.00  ...
# 53183  Translate_Views_FixedLight/Scene10_2.0_0030_-0...     -0.90  ...
#
#       corr_resp  hit      rt  subj      date           time  delta  \
# 384           j  0.0  1530.0   914  20220511  1652269532447   0.50
# 385           j  0.0  1326.3   914  20220511  1652269532447   0.55
# 386           f  1.0  1416.0   914  20220511  1652269532447   0.00
# 387           f  1.0  1727.5   914  20220511  1652269532447   0.00
# 388           j  1.0  1468.4   914  20220511  1652269532447   0.55
# ...         ...  ...     ...   ...       ...            ...    ...
# 53178         j  1.0   481.2  1459  20220910  1662807993840   0.95
# 53180         j  1.0   475.6  1459  20220910  1662807993840   0.95
# 53181         f  1.0   398.3  1459  20220910  1662807993840   0.00
# 53182         f  1.0   344.6  1459  20220910  1662807993840   0.00
# 53183         j  1.0   561.5  1459  20220910  1662807993840   0.90
#
#        trial_type  resp_diff is_diff
# 384          diff          0       1
# 385          diff          0       1
# 386          same          0       0
# 387          same          0       0
# 388          diff          1       1
# ...           ...        ...     ...
# 53178        diff          1       1
# 53180        diff          1       1
# 53181        same          0       0
# 53182        same          0       0
# 53183        diff          1       1
#
# [28849 rows x 22 columns]

# %%
formula = sdt_constrained_formula()

# %%
glm_res = fit_sdt_probit_glm(df_sdt, formula=formula, cluster_col='subj')
# Out:
# /opt/anaconda3/envs/scenecontext/lib/python3.11/site-packages/statsmodels/genmod/families/links.py:13: FutureWarning: The probit link alias is deprecated. Use Probit instead. The probit link alias will be removed after the 0.15.0 release.
#   warnings.warn(

# %%
glm_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              resp_diff   No. Observations:                28849
# Model:                            GLM   Df Residuals:                    28842
# Model Family:                Binomial   Df Model:                            6
# Link Function:                 probit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -17801.
# Date:                Sun, 09 Nov 2025   Deviance:                       35602.
# Time:                        14:09:15   Pearson chi2:                 2.88e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1332
# Covariance Type:              cluster
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.7443      0.038    -19.385      0.000      -0.820      -0.669
# C(cond)[T.0]                   0.2010      0.034      5.883      0.000       0.134       0.268
# C(group)[T.0.5]                0.0140      0.041      0.340      0.734      -0.067       0.095
# C(group)[T.0.75]               0.0473      0.043      1.111      0.266      -0.036       0.131
# is_diff                        0.9128      0.063     14.538      0.000       0.790       1.036
# is_diff:delta                  0.1038      0.093      1.111      0.267      -0.079       0.287
# is_diff:delta:C(cond)[T.0]    -0.0636      0.047     -1.347      0.178      -0.156       0.029
# ==============================================================================================
# """

# %%
dgrid = reference_delta_grid(df_sdt, lo=0.2, hi=0.8, n=7)

# %%
dgrid
# Out:
# array([0.   , 0.   , 0.   , 0.175, 0.55 , 0.7  , 0.85 ])

# %%
out = sdt_from_model(glm_res, df_sdt, dgrid=dgrid, cond_levels=(1, 0))

# %%
out
# Out:
# {1: {'H': 0.587958912002186,
#   'FA': 0.23457846810167818,
#   'dprime': np.float64(0.9461491111718603),
#   'criterion': np.float64(0.2507768986806844)},
#  0: {'H': 0.6564223392911576,
#   'FA': 0.3005293418957524,
#   'dprime': np.float64(0.9255971791649285),
#   'criterion': np.float64(0.060080087787280106)}}
